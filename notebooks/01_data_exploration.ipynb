# %% [markdown]
# # Text2SQL Data Exploration
#
# This notebook explores the Text2SQL datasets and demonstrates data loading and preprocessing.

# %%
import sys
sys.path.append('..')

from text2sql.data.datasets import load_dataset
from text2sql.data.preprocessing import preprocess_data

# %% [markdown]
# ## Load Dataset

# %%
# Load Spider dataset
train_data = load_dataset('spider', split='train')
print(f"Loaded {len(train_data)} training examples")

# %% [markdown]
# ## Explore Examples

# %%
# Show first example
example = train_data[0]
print(f"Question: {example.question}")
print(f"Query: {example.query}")
print(f"Database: {example.db_id}")
